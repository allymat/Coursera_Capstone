# %% [markdown]
# <h1>Coursera Capstone: Week 3</h1>

# %% [markdown]
# <h1>NOTE: This workbook includes all three parts of assignment</h1>

# %% [markdown]
# <h2>Part 1 of assigment: Get postal code data and remove duplicates etc.</h2>

# %% [markdown]
# <h3>First, import libraries and set Pandas options</h3>

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)
pd.set_option('display.expand_frame_repr', False)

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# <h3>Now use BeautifulSoup to scrape the Wikipedia page for postcode/borough/neighborhood data</h3>

# %%
import urllib.request
from bs4 import BeautifulSoup

# request contents of page from Wikipedia
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
req = urllib.request.urlopen(url)
article = req.read().decode()

# load article, turn into soup and get the <table>
soup = BeautifulSoup(article, 'html.parser')
tables = soup.find_all('table', class_='sortable')

# search through the tables for the one with the headings we want
for table in tables:
    ths = table.find_all('th')
    headings = [th.text.strip() for th in ths]
    if headings[:3] == ['Postcode', 'Borough', 'Neighborhood']:
        break

# create a new dataframe and populate
df = pd.DataFrame(columns=['Postcode', 'Borough', 'Neighborhood'])
for tr in table.find_all('tr'):
    tds = tr.find_all('td')
    if not tds:
        continue
    postcode, borough, neighborhood = [td.text.strip() for td in tds[:3]]
    if 'Not assigned' not in borough:
        if 'Not assigned' in neighborhood:
            neighborhood = borough
        df.loc[len(df)] = [postcode, borough, neighborhood]

# %%
# display our table
from tabulate import tabulate
print(tabulate(df, headers='keys', tablefmt='psql'))
# Out:
# +-----+------------+------------------+---------------------------------------------------+
# |     | Postcode   | Borough          | Neighborhood                                      |
# |-----+------------+------------------+---------------------------------------------------|
# |   0 | M3A        | North York       | Parkwoods                                         |
# |   1 | M4A        | North York       | Victoria Village                                  |
# |   2 | M5A        | Downtown Toronto | Harbourfront                                      |
# |   3 | M5A        | Downtown Toronto | Regent Park                                       |
# |   4 | M6A        | North York       | Lawrence Heights                                  |
# |   5 | M6A        | North York       | Lawrence Manor                                    |
# |   6 | M7A        | Queen's Park     | Queen's Park                                      |
# |   7 | M9A        | Etobicoke        | Islington Avenue                                  |
# |   8 | M1B        | Scarborough      | Rouge                                             |
# |   9 | M1B        | Scarborough      | Malvern                                           |
# |  10 | M3B        | North York       | Don Mills North                                   |
# |  11 | M4B        | East York        | Woodbine Gardens                                  |
# |  12 | M4B        | East York        | Parkview Hill                                     |
# |  13 | M5B        | Downtown Toronto | Ryerson                                           |
# |  14 | M5B        | Downtown Toronto | Garden District                                   |
# |  15 | M6B        | North York       | Glencairn                                         |
# |  16 | M9B        | Etobicoke        | Cloverdale                                        |
# |  17 | M9B        | Etobicoke        | Islington                                         |
# |  18 | M9B        | Etobicoke        | Martin Grove                                      |
# |  19 | M9B        | Etobicoke        | Princess Gardens                                  |
# |  20 | M9B        | Etobicoke        | West Deane Park                                   |
# |  21 | M1C        | Scarborough      | Highland Creek                                    |
# |  22 | M1C        | Scarborough      | Rouge Hill                                        |
# |  23 | M1C        | Scarborough      | Port Union                                        |
# |  24 | M3C        | North York       | Flemingdon Park                                   |
# |  25 | M3C        | North York       | Don Mills South                                   |
# |  26 | M4C        | East York        | Woodbine Heights                                  |
# |  27 | M5C        | Downtown Toronto | St. James Town                                    |
# |  28 | M6C        | York             | Humewood-Cedarvale                                |
# |  29 | M9C        | Etobicoke        | Bloordale Gardens                                 |
# |  30 | M9C        | Etobicoke        | Eringate                                          |
# |  31 | M9C        | Etobicoke        | Markland Wood                                     |
# |  32 | M9C        | Etobicoke        | Old Burnhamthorpe                                 |
# |  33 | M1E        | Scarborough      | Guildwood                                         |
# |  34 | M1E        | Scarborough      | Morningside                                       |
# |  35 | M1E        | Scarborough      | West Hill                                         |
# |  36 | M4E        | East Toronto     | The Beaches                                       |
# |  37 | M5E        | Downtown Toronto | Berczy Park                                       |
# |  38 | M6E        | York             | Caledonia-Fairbanks                               |
# |  39 | M1G        | Scarborough      | Woburn                                            |
# |  40 | M4G        | East York        | Leaside                                           |
# |  41 | M5G        | Downtown Toronto | Central Bay Street                                |
# |  42 | M6G        | Downtown Toronto | Christie                                          |
# |  43 | M1H        | Scarborough      | Cedarbrae                                         |
# |  44 | M2H        | North York       | Hillcrest Village                                 |
# |  45 | M3H        | North York       | Bathurst Manor                                    |
# |  46 | M3H        | North York       | Downsview North                                   |
# |  47 | M3H        | North York       | Wilson Heights                                    |
# |  48 | M4H        | East York        | Thorncliffe Park                                  |
# |  49 | M5H        | Downtown Toronto | Adelaide                                          |
# |  50 | M5H        | Downtown Toronto | King                                              |
# |  51 | M5H        | Downtown Toronto | Richmond                                          |
# |  52 | M6H        | West Toronto     | Dovercourt Village                                |
# |  53 | M6H        | West Toronto     | Dufferin                                          |
# |  54 | M1J        | Scarborough      | Scarborough Village                               |
# |  55 | M2J        | North York       | Fairview                                          |
# |  56 | M2J        | North York       | Henry Farm                                        |
# |  57 | M2J        | North York       | Oriole                                            |
# |  58 | M3J        | North York       | Northwood Park                                    |
# |  59 | M3J        | North York       | York University                                   |
# |  60 | M4J        | East York        | East Toronto                                      |
# |  61 | M5J        | Downtown Toronto | Harbourfront East                                 |
# |  62 | M5J        | Downtown Toronto | Toronto Islands                                   |
# |  63 | M5J        | Downtown Toronto | Union Station                                     |
# |  64 | M6J        | West Toronto     | Little Portugal                                   |
# |  65 | M6J        | West Toronto     | Trinity                                           |
# |  66 | M1K        | Scarborough      | East Birchmount Park                              |
# |  67 | M1K        | Scarborough      | Ionview                                           |
# |  68 | M1K        | Scarborough      | Kennedy Park                                      |
# |  69 | M2K        | North York       | Bayview Village                                   |
# |  70 | M3K        | North York       | CFB Toronto                                       |
# |  71 | M3K        | North York       | Downsview East                                    |
# |  72 | M4K        | East Toronto     | The Danforth West                                 |
# |  73 | M4K        | East Toronto     | Riverdale                                         |
# |  74 | M5K        | Downtown Toronto | Design Exchange                                   |
# |  75 | M5K        | Downtown Toronto | Toronto Dominion Centre                           |
# |  76 | M6K        | West Toronto     | Brockton                                          |
# |  77 | M6K        | West Toronto     | Exhibition Place                                  |
# |  78 | M6K        | West Toronto     | Parkdale Village                                  |
# |  79 | M1L        | Scarborough      | Clairlea                                          |
# |  80 | M1L        | Scarborough      | Golden Mile                                       |
# |  81 | M1L        | Scarborough      | Oakridge                                          |
# |  82 | M2L        | North York       | Silver Hills                                      |
# |  83 | M2L        | North York       | York Mills                                        |
# |  84 | M3L        | North York       | Downsview West                                    |
# |  85 | M4L        | East Toronto     | The Beaches West                                  |
# |  86 | M4L        | East Toronto     | India Bazaar                                      |
# |  87 | M5L        | Downtown Toronto | Commerce Court                                    |
# |  88 | M5L        | Downtown Toronto | Victoria Hotel                                    |
# |  89 | M6L        | North York       | Downsview                                         |
# |  90 | M6L        | North York       | North Park                                        |
# |  91 | M6L        | North York       | Upwood Park                                       |
# |  92 | M9L        | North York       | Humber Summit                                     |
# |  93 | M1M        | Scarborough      | Cliffcrest                                        |
# |  94 | M1M        | Scarborough      | Cliffside                                         |
# |  95 | M1M        | Scarborough      | Scarborough Village West                          |
# |  96 | M2M        | North York       | Newtonbrook                                       |
# |  97 | M2M        | North York       | Willowdale                                        |
# |  98 | M3M        | North York       | Downsview Central                                 |
# |  99 | M4M        | East Toronto     | Studio District                                   |
# | 100 | M5M        | North York       | Bedford Park                                      |
# | 101 | M5M        | North York       | Lawrence Manor East                               |
# | 102 | M6M        | York             | Del Ray                                           |
# | 103 | M6M        | York             | Keelesdale                                        |
# | 104 | M6M        | York             | Mount Dennis                                      |
# | 105 | M6M        | York             | Silverthorn                                       |
# | 106 | M9M        | North York       | Emery                                             |
# | 107 | M9M        | North York       | Humberlea                                         |
# | 108 | M1N        | Scarborough      | Birch Cliff                                       |
# | 109 | M1N        | Scarborough      | Cliffside West                                    |
# | 110 | M2N        | North York       | Willowdale South                                  |
# | 111 | M3N        | North York       | Downsview Northwest                               |
# | 112 | M4N        | Central Toronto  | Lawrence Park                                     |
# | 113 | M5N        | Central Toronto  | Roselawn                                          |
# | 114 | M6N        | York             | The Junction North                                |
# | 115 | M6N        | York             | Runnymede                                         |
# | 116 | M9N        | York             | Weston                                            |
# | 117 | M1P        | Scarborough      | Dorset Park                                       |
# | 118 | M1P        | Scarborough      | Scarborough Town Centre                           |
# | 119 | M1P        | Scarborough      | Wexford Heights                                   |
# | 120 | M2P        | North York       | York Mills West                                   |
# | 121 | M4P        | Central Toronto  | Davisville North                                  |
# | 122 | M5P        | Central Toronto  | Forest Hill North                                 |
# | 123 | M5P        | Central Toronto  | Forest Hill West                                  |
# | 124 | M6P        | West Toronto     | High Park                                         |
# | 125 | M6P        | West Toronto     | The Junction South                                |
# | 126 | M9P        | Etobicoke        | Westmount                                         |
# | 127 | M1R        | Scarborough      | Maryvale                                          |
# | 128 | M1R        | Scarborough      | Wexford                                           |
# | 129 | M2R        | North York       | Willowdale West                                   |
# | 130 | M4R        | Central Toronto  | North Toronto West                                |
# | 131 | M5R        | Central Toronto  | The Annex                                         |
# | 132 | M5R        | Central Toronto  | North Midtown                                     |
# | 133 | M5R        | Central Toronto  | Yorkville                                         |
# | 134 | M6R        | West Toronto     | Parkdale                                          |
# | 135 | M6R        | West Toronto     | Roncesvalles                                      |
# | 136 | M7R        | Mississauga      | Canada Post Gateway Processing Centre             |
# | 137 | M9R        | Etobicoke        | Kingsview Village                                 |
# | 138 | M9R        | Etobicoke        | Martin Grove Gardens                              |
# | 139 | M9R        | Etobicoke        | Richview Gardens                                  |
# | 140 | M9R        | Etobicoke        | St. Phillips                                      |
# | 141 | M1S        | Scarborough      | Agincourt                                         |
# | 142 | M4S        | Central Toronto  | Davisville                                        |
# | 143 | M5S        | Downtown Toronto | Harbord                                           |
# | 144 | M5S        | Downtown Toronto | University of Toronto                             |
# | 145 | M6S        | West Toronto     | Runnymede                                         |
# | 146 | M6S        | West Toronto     | Swansea                                           |
# | 147 | M1T        | Scarborough      | Clarks Corners                                    |
# | 148 | M1T        | Scarborough      | Sullivan                                          |
# | 149 | M1T        | Scarborough      | Tam O'Shanter                                     |
# | 150 | M4T        | Central Toronto  | Moore Park                                        |
# | 151 | M4T        | Central Toronto  | Summerhill East                                   |
# | 152 | M5T        | Downtown Toronto | Chinatown                                         |
# | 153 | M5T        | Downtown Toronto | Grange Park                                       |
# | 154 | M5T        | Downtown Toronto | Kensington Market                                 |
# | 155 | M1V        | Scarborough      | Agincourt North                                   |
# | 156 | M1V        | Scarborough      | L'Amoreaux East                                   |
# | 157 | M1V        | Scarborough      | Milliken                                          |
# | 158 | M1V        | Scarborough      | Steeles East                                      |
# | 159 | M4V        | Central Toronto  | Deer Park                                         |
# | 160 | M4V        | Central Toronto  | Forest Hill SE                                    |
# | 161 | M4V        | Central Toronto  | Rathnelly                                         |
# | 162 | M4V        | Central Toronto  | South Hill                                        |
# | 163 | M4V        | Central Toronto  | Summerhill West                                   |
# | 164 | M5V        | Downtown Toronto | CN Tower                                          |
# | 165 | M5V        | Downtown Toronto | Bathurst Quay                                     |
# | 166 | M5V        | Downtown Toronto | Island airport                                    |
# | 167 | M5V        | Downtown Toronto | Harbourfront West                                 |
# | 168 | M5V        | Downtown Toronto | King and Spadina                                  |
# | 169 | M5V        | Downtown Toronto | Railway Lands                                     |
# | 170 | M5V        | Downtown Toronto | South Niagara                                     |
# | 171 | M8V        | Etobicoke        | Humber Bay Shores                                 |
# | 172 | M8V        | Etobicoke        | Mimico South                                      |
# | 173 | M8V        | Etobicoke        | New Toronto                                       |
# | 174 | M9V        | Etobicoke        | Albion Gardens                                    |
# | 175 | M9V        | Etobicoke        | Beaumond Heights                                  |
# | 176 | M9V        | Etobicoke        | Humbergate                                        |
# | 177 | M9V        | Etobicoke        | Jamestown                                         |
# | 178 | M9V        | Etobicoke        | Mount Olive                                       |
# | 179 | M9V        | Etobicoke        | Silverstone                                       |
# | 180 | M9V        | Etobicoke        | South Steeles                                     |
# | 181 | M9V        | Etobicoke        | Thistletown                                       |
# | 182 | M1W        | Scarborough      | L'Amoreaux West                                   |
# | 183 | M4W        | Downtown Toronto | Rosedale                                          |
# | 184 | M5W        | Downtown Toronto | Stn A PO Boxes 25 The Esplanade                   |
# | 185 | M8W        | Etobicoke        | Alderwood                                         |
# | 186 | M8W        | Etobicoke        | Long Branch                                       |
# | 187 | M9W        | Etobicoke        | Northwest                                         |
# | 188 | M1X        | Scarborough      | Upper Rouge                                       |
# | 189 | M4X        | Downtown Toronto | Cabbagetown                                       |
# | 190 | M4X        | Downtown Toronto | St. James Town                                    |
# | 191 | M5X        | Downtown Toronto | First Canadian Place                              |
# | 192 | M5X        | Downtown Toronto | Underground city                                  |
# | 193 | M8X        | Etobicoke        | The Kingsway                                      |
# | 194 | M8X        | Etobicoke        | Montgomery Road                                   |
# | 195 | M8X        | Etobicoke        | Old Mill North                                    |
# | 196 | M4Y        | Downtown Toronto | Church and Wellesley                              |
# | 197 | M7Y        | East Toronto     | Business Reply Mail Processing Centre 969 Eastern |
# | 198 | M8Y        | Etobicoke        | Humber Bay                                        |
# | 199 | M8Y        | Etobicoke        | King's Mill Park                                  |
# | 200 | M8Y        | Etobicoke        | Kingsway Park South East                          |
# | 201 | M8Y        | Etobicoke        | Mimico NE                                         |
# | 202 | M8Y        | Etobicoke        | Old Mill South                                    |
# | 203 | M8Y        | Etobicoke        | The Queensway East                                |
# | 204 | M8Y        | Etobicoke        | Royal York South East                             |
# | 205 | M8Y        | Etobicoke        | Sunnylea                                          |
# | 206 | M8Z        | Etobicoke        | Kingsway Park South West                          |
# | 207 | M8Z        | Etobicoke        | Mimico NW                                         |
# | 208 | M8Z        | Etobicoke        | The Queensway West                                |
# | 209 | M8Z        | Etobicoke        | Royal York South West                             |
# | 210 | M8Z        | Etobicoke        | South of Bloor                                    |
# +-----+------------+------------------+---------------------------------------------------+

# %% [markdown]
# <h3>Next, we create a dataframe to concatenate neighborhoods and eliminate duplicates</h3>

# %%
# create final dataframe to be used to concatenate neighborhoods while eliminating duplicates
df_final = pd.DataFrame(columns=['Postcode', 'Borough', 'Neighborhood'])

# now iterate and find any duplicate rows
for index, row in df.iterrows():
    dupe_df = df_final.loc[df_final['Postcode'] == row['Postcode']]
    if dupe_df.empty:
        # no duplicate Postcode found - add as a new row
        # print ("No duplicate - adding as new row: " + row['Neighborhood']) # uncomment for debugging
        df_final.loc[len(df_final)] = [row['Postcode'], row['Borough'], row['Neighborhood']]
    else:
        # duplicate Postcode was found - concatenate the Neighborhood to the existing row
        # print ("Duplicate found for " + row['Postcode'] + " - adding neighborhood: " + dupe_row['Neighborhood']) # uncomment for debugging
        for dupe_index, dupe_row in dupe_df.iterrows():
            df_final.loc[dupe_index] = [row['Postcode'], row['Borough'], row['Neighborhood'] + "," + dupe_row['Neighborhood']]
        
print(tabulate(df_final, headers='keys', tablefmt='psql'))
# Out:
# +-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+
# |     | Postcode   | Borough          | Neighborhood                                                                                                                    |
# |-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------|
# |   0 | M3A        | North York       | Parkwoods                                                                                                                       |
# |   1 | M4A        | North York       | Victoria Village                                                                                                                |
# |   2 | M5A        | Downtown Toronto | Regent Park,Harbourfront                                                                                                        |
# |   3 | M6A        | North York       | Lawrence Manor,Lawrence Heights                                                                                                 |
# |   4 | M7A        | Queen's Park     | Queen's Park                                                                                                                    |
# |   5 | M9A        | Etobicoke        | Islington Avenue                                                                                                                |
# |   6 | M1B        | Scarborough      | Malvern,Rouge                                                                                                                   |
# |   7 | M3B        | North York       | Don Mills North                                                                                                                 |
# |   8 | M4B        | East York        | Parkview Hill,Woodbine Gardens                                                                                                  |
# |   9 | M5B        | Downtown Toronto | Garden District,Ryerson                                                                                                         |
# |  10 | M6B        | North York       | Glencairn                                                                                                                       |
# |  11 | M9B        | Etobicoke        | West Deane Park,Princess Gardens,Martin Grove,Islington,Cloverdale                                                              |
# |  12 | M1C        | Scarborough      | Port Union,Rouge Hill,Highland Creek                                                                                            |
# |  13 | M3C        | North York       | Don Mills South,Flemingdon Park                                                                                                 |
# |  14 | M4C        | East York        | Woodbine Heights                                                                                                                |
# |  15 | M5C        | Downtown Toronto | St. James Town                                                                                                                  |
# |  16 | M6C        | York             | Humewood-Cedarvale                                                                                                              |
# |  17 | M9C        | Etobicoke        | Old Burnhamthorpe,Markland Wood,Eringate,Bloordale Gardens                                                                      |
# |  18 | M1E        | Scarborough      | West Hill,Morningside,Guildwood                                                                                                 |
# |  19 | M4E        | East Toronto     | The Beaches                                                                                                                     |
# |  20 | M5E        | Downtown Toronto | Berczy Park                                                                                                                     |
# |  21 | M6E        | York             | Caledonia-Fairbanks                                                                                                             |
# |  22 | M1G        | Scarborough      | Woburn                                                                                                                          |
# |  23 | M4G        | East York        | Leaside                                                                                                                         |
# |  24 | M5G        | Downtown Toronto | Central Bay Street                                                                                                              |
# |  25 | M6G        | Downtown Toronto | Christie                                                                                                                        |
# |  26 | M1H        | Scarborough      | Cedarbrae                                                                                                                       |
# |  27 | M2H        | North York       | Hillcrest Village                                                                                                               |
# |  28 | M3H        | North York       | Wilson Heights,Downsview North,Bathurst Manor                                                                                   |
# |  29 | M4H        | East York        | Thorncliffe Park                                                                                                                |
# |  30 | M5H        | Downtown Toronto | Richmond,King,Adelaide                                                                                                          |
# |  31 | M6H        | West Toronto     | Dufferin,Dovercourt Village                                                                                                     |
# |  32 | M1J        | Scarborough      | Scarborough Village                                                                                                             |
# |  33 | M2J        | North York       | Oriole,Henry Farm,Fairview                                                                                                      |
# |  34 | M3J        | North York       | York University,Northwood Park                                                                                                  |
# |  35 | M4J        | East York        | East Toronto                                                                                                                    |
# |  36 | M5J        | Downtown Toronto | Union Station,Toronto Islands,Harbourfront East                                                                                 |
# |  37 | M6J        | West Toronto     | Trinity,Little Portugal                                                                                                         |
# |  38 | M1K        | Scarborough      | Kennedy Park,Ionview,East Birchmount Park                                                                                       |
# |  39 | M2K        | North York       | Bayview Village                                                                                                                 |
# |  40 | M3K        | North York       | Downsview East,CFB Toronto                                                                                                      |
# |  41 | M4K        | East Toronto     | Riverdale,The Danforth West                                                                                                     |
# |  42 | M5K        | Downtown Toronto | Toronto Dominion Centre,Design Exchange                                                                                         |
# |  43 | M6K        | West Toronto     | Parkdale Village,Exhibition Place,Brockton                                                                                      |
# |  44 | M1L        | Scarborough      | Oakridge,Golden Mile,Clairlea                                                                                                   |
# |  45 | M2L        | North York       | York Mills,Silver Hills                                                                                                         |
# |  46 | M3L        | North York       | Downsview West                                                                                                                  |
# |  47 | M4L        | East Toronto     | India Bazaar,The Beaches West                                                                                                   |
# |  48 | M5L        | Downtown Toronto | Victoria Hotel,Commerce Court                                                                                                   |
# |  49 | M6L        | North York       | Upwood Park,North Park,Downsview                                                                                                |
# |  50 | M9L        | North York       | Humber Summit                                                                                                                   |
# |  51 | M1M        | Scarborough      | Scarborough Village West,Cliffside,Cliffcrest                                                                                   |
# |  52 | M2M        | North York       | Willowdale,Newtonbrook                                                                                                          |
# |  53 | M3M        | North York       | Downsview Central                                                                                                               |
# |  54 | M4M        | East Toronto     | Studio District                                                                                                                 |
# |  55 | M5M        | North York       | Lawrence Manor East,Bedford Park                                                                                                |
# |  56 | M6M        | York             | Silverthorn,Mount Dennis,Keelesdale,Del Ray                                                                                     |
# |  57 | M9M        | North York       | Humberlea,Emery                                                                                                                 |
# |  58 | M1N        | Scarborough      | Cliffside West,Birch Cliff                                                                                                      |
# |  59 | M2N        | North York       | Willowdale South                                                                                                                |
# |  60 | M3N        | North York       | Downsview Northwest                                                                                                             |
# |  61 | M4N        | Central Toronto  | Lawrence Park                                                                                                                   |
# |  62 | M5N        | Central Toronto  | Roselawn                                                                                                                        |
# |  63 | M6N        | York             | Runnymede,The Junction North                                                                                                    |
# |  64 | M9N        | York             | Weston                                                                                                                          |
# |  65 | M1P        | Scarborough      | Wexford Heights,Scarborough Town Centre,Dorset Park                                                                             |
# |  66 | M2P        | North York       | York Mills West                                                                                                                 |
# |  67 | M4P        | Central Toronto  | Davisville North                                                                                                                |
# |  68 | M5P        | Central Toronto  | Forest Hill West,Forest Hill North                                                                                              |
# |  69 | M6P        | West Toronto     | The Junction South,High Park                                                                                                    |
# |  70 | M9P        | Etobicoke        | Westmount                                                                                                                       |
# |  71 | M1R        | Scarborough      | Wexford,Maryvale                                                                                                                |
# |  72 | M2R        | North York       | Willowdale West                                                                                                                 |
# |  73 | M4R        | Central Toronto  | North Toronto West                                                                                                              |
# |  74 | M5R        | Central Toronto  | Yorkville,North Midtown,The Annex                                                                                               |
# |  75 | M6R        | West Toronto     | Roncesvalles,Parkdale                                                                                                           |
# |  76 | M7R        | Mississauga      | Canada Post Gateway Processing Centre                                                                                           |
# |  77 | M9R        | Etobicoke        | St. Phillips,Richview Gardens,Martin Grove Gardens,Kingsview Village                                                            |
# |  78 | M1S        | Scarborough      | Agincourt                                                                                                                       |
# |  79 | M4S        | Central Toronto  | Davisville                                                                                                                      |
# |  80 | M5S        | Downtown Toronto | University of Toronto,Harbord                                                                                                   |
# |  81 | M6S        | West Toronto     | Swansea,Runnymede                                                                                                               |
# |  82 | M1T        | Scarborough      | Tam O'Shanter,Sullivan,Clarks Corners                                                                                           |
# |  83 | M4T        | Central Toronto  | Summerhill East,Moore Park                                                                                                      |
# |  84 | M5T        | Downtown Toronto | Kensington Market,Grange Park,Chinatown                                                                                         |
# |  85 | M1V        | Scarborough      | Steeles East,Milliken,L'Amoreaux East,Agincourt North                                                                           |
# |  86 | M4V        | Central Toronto  | Summerhill West,South Hill,Rathnelly,Forest Hill SE,Deer Park                                                                   |
# |  87 | M5V        | Downtown Toronto | South Niagara,Railway Lands,King and Spadina,Harbourfront West,Island airport,Bathurst Quay,CN Tower                            |
# |  88 | M8V        | Etobicoke        | New Toronto,Mimico South,Humber Bay Shores                                                                                      |
# |  89 | M9V        | Etobicoke        | Thistletown,South Steeles,Silverstone,Mount Olive,Jamestown,Humbergate,Beaumond Heights,Albion Gardens                          |
# |  90 | M1W        | Scarborough      | L'Amoreaux West                                                                                                                 |
# |  91 | M4W        | Downtown Toronto | Rosedale                                                                                                                        |
# |  92 | M5W        | Downtown Toronto | Stn A PO Boxes 25 The Esplanade                                                                                                 |
# |  93 | M8W        | Etobicoke        | Long Branch,Alderwood                                                                                                           |
# |  94 | M9W        | Etobicoke        | Northwest                                                                                                                       |
# |  95 | M1X        | Scarborough      | Upper Rouge                                                                                                                     |
# |  96 | M4X        | Downtown Toronto | St. James Town,Cabbagetown                                                                                                      |
# |  97 | M5X        | Downtown Toronto | Underground city,First Canadian Place                                                                                           |
# |  98 | M8X        | Etobicoke        | Old Mill North,Montgomery Road,The Kingsway                                                                                     |
# |  99 | M4Y        | Downtown Toronto | Church and Wellesley                                                                                                            |
# | 100 | M7Y        | East Toronto     | Business Reply Mail Processing Centre 969 Eastern                                                                               |
# | 101 | M8Y        | Etobicoke        | Sunnylea,Royal York South East,The Queensway East,Old Mill South,Mimico NE,Kingsway Park South East,King's Mill Park,Humber Bay |
# | 102 | M8Z        | Etobicoke        | South of Bloor,Royal York South West,The Queensway West,Mimico NW,Kingsway Park South West                                      |
# +-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# <h3>And, now display the shape of our generated dataframe</h3>

# %%
# display the shape of our final dataframe
df_final.shape
# Out:
# (103, 3)

# %% [markdown]
# <h2>Part 2 of assignment: Add coordinates to dataframe</h2>

# %% [markdown]
# <h3>Attempt to use 'geopy' libraries to get coordinates first - please be patient - this takes a minute or two!</h3>

# %% [markdown]
# <h3>NOTE: The Nominatim interface only returns a small number of coordinates no matter how many times we try - so next step will be to use .csv file to fill in the blanks</h3>

# %%
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't loaded geopy previously

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# add new columns and initialize
df_final['Latitude'] = 0.0
df_final['Longitude'] = 0.0

for index, row in df_final.iterrows():
    address = "{} {}, Toronto, Ontario".format(row['Postcode'], row['Borough'])
    geolocator = Nominatim(user_agent="ny_explorer")
    location = None
    
    #while (location is None): #note - this retry logic doesn't seem to work - many postcodes won't return a valid lat/long response via 'Nominatim' calls
    location = geolocator.geocode(address)
    
    if location:
        latitude = location.latitude
        longitude = location.longitude
        print ("O", end=""), # let the user know that we found coordinates
        df_final.loc[index, 'Latitude'] = latitude
        df_final.loc[index, 'Longitude'] = longitude
    else:
        print (".", end=""), # let the user know we didn't find coordinates
        
print("") # add cr/lf and start new line        
print(tabulate(df_final, headers='keys', tablefmt='psql'))
# Out:
# ....O.O.....OO...O..O.......O.O..OO........O........O......O...O.....O.......O...O........O...O........
# +-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+------------+-------------+
# |     | Postcode   | Borough          | Neighborhood                                                                                                                    |   Latitude |   Longitude |
# |-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+------------+-------------|
# |   0 | M3A        | North York       | Parkwoods                                                                                                                       |     0      |      0      |
# |   1 | M4A        | North York       | Victoria Village                                                                                                                |     0      |      0      |
# |   2 | M5A        | Downtown Toronto | Regent Park,Harbourfront                                                                                                        |     0      |      0      |
# |   3 | M6A        | North York       | Lawrence Manor,Lawrence Heights                                                                                                 |     0      |      0      |
# |   4 | M7A        | Queen's Park     | Queen's Park                                                                                                                    |    43.66   |    -79.3904 |
# |   5 | M9A        | Etobicoke        | Islington Avenue                                                                                                                |     0      |      0      |
# |   6 | M1B        | Scarborough      | Malvern,Rouge                                                                                                                   |    43.7731 |    -79.2578 |
# |   7 | M3B        | North York       | Don Mills North                                                                                                                 |     0      |      0      |
# |   8 | M4B        | East York        | Parkview Hill,Woodbine Gardens                                                                                                  |     0      |      0      |
# |   9 | M5B        | Downtown Toronto | Garden District,Ryerson                                                                                                         |     0      |      0      |
# |  10 | M6B        | North York       | Glencairn                                                                                                                       |     0      |      0      |
# |  11 | M9B        | Etobicoke        | West Deane Park,Princess Gardens,Martin Grove,Islington,Cloverdale                                                              |     0      |      0      |
# |  12 | M1C        | Scarborough      | Port Union,Rouge Hill,Highland Creek                                                                                            |    43.7731 |    -79.2578 |
# |  13 | M3C        | North York       | Don Mills South,Flemingdon Park                                                                                                 |    43.7328 |    -79.347  |
# |  14 | M4C        | East York        | Woodbine Heights                                                                                                                |     0      |      0      |
# |  15 | M5C        | Downtown Toronto | St. James Town                                                                                                                  |     0      |      0      |
# |  16 | M6C        | York             | Humewood-Cedarvale                                                                                                              |     0      |      0      |
# |  17 | M9C        | Etobicoke        | Old Burnhamthorpe,Markland Wood,Eringate,Bloordale Gardens                                                                      |    43.6286 |    -79.4853 |
# |  18 | M1E        | Scarborough      | West Hill,Morningside,Guildwood                                                                                                 |     0      |      0      |
# |  19 | M4E        | East Toronto     | The Beaches                                                                                                                     |     0      |      0      |
# |  20 | M5E        | Downtown Toronto | Berczy Park                                                                                                                     |    43.6544 |    -79.3805 |
# |  21 | M6E        | York             | Caledonia-Fairbanks                                                                                                             |     0      |      0      |
# |  22 | M1G        | Scarborough      | Woburn                                                                                                                          |     0      |      0      |
# |  23 | M4G        | East York        | Leaside                                                                                                                         |     0      |      0      |
# |  24 | M5G        | Downtown Toronto | Central Bay Street                                                                                                              |     0      |      0      |
# |  25 | M6G        | Downtown Toronto | Christie                                                                                                                        |     0      |      0      |
# |  26 | M1H        | Scarborough      | Cedarbrae                                                                                                                       |     0      |      0      |
# |  27 | M2H        | North York       | Hillcrest Village                                                                                                               |     0      |      0      |
# |  28 | M3H        | North York       | Wilson Heights,Downsview North,Bathurst Manor                                                                                   |    43.7562 |    -79.4398 |
# |  29 | M4H        | East York        | Thorncliffe Park                                                                                                                |     0      |      0      |
# |  30 | M5H        | Downtown Toronto | Richmond,King,Adelaide                                                                                                          |    43.652  |    -79.3856 |
# |  31 | M6H        | West Toronto     | Dufferin,Dovercourt Village                                                                                                     |     0      |      0      |
# |  32 | M1J        | Scarborough      | Scarborough Village                                                                                                             |     0      |      0      |
# |  33 | M2J        | North York       | Oriole,Henry Farm,Fairview                                                                                                      |    43.724  |    -79.4831 |
# |  34 | M3J        | North York       | York University,Northwood Park                                                                                                  |    43.7756 |    -79.4935 |
# |  35 | M4J        | East York        | East Toronto                                                                                                                    |     0      |      0      |
# |  36 | M5J        | Downtown Toronto | Union Station,Toronto Islands,Harbourfront East                                                                                 |     0      |      0      |
# |  37 | M6J        | West Toronto     | Trinity,Little Portugal                                                                                                         |     0      |      0      |
# |  38 | M1K        | Scarborough      | Kennedy Park,Ionview,East Birchmount Park                                                                                       |     0      |      0      |
# |  39 | M2K        | North York       | Bayview Village                                                                                                                 |     0      |      0      |
# |  40 | M3K        | North York       | Downsview East,CFB Toronto                                                                                                      |     0      |      0      |
# |  41 | M4K        | East Toronto     | Riverdale,The Danforth West                                                                                                     |     0      |      0      |
# |  42 | M5K        | Downtown Toronto | Toronto Dominion Centre,Design Exchange                                                                                         |     0      |      0      |
# |  43 | M6K        | West Toronto     | Parkdale Village,Exhibition Place,Brockton                                                                                      |    43.6371 |    -79.435  |
# |  44 | M1L        | Scarborough      | Oakridge,Golden Mile,Clairlea                                                                                                   |     0      |      0      |
# |  45 | M2L        | North York       | York Mills,Silver Hills                                                                                                         |     0      |      0      |
# |  46 | M3L        | North York       | Downsview West                                                                                                                  |     0      |      0      |
# |  47 | M4L        | East Toronto     | India Bazaar,The Beaches West                                                                                                   |     0      |      0      |
# |  48 | M5L        | Downtown Toronto | Victoria Hotel,Commerce Court                                                                                                   |     0      |      0      |
# |  49 | M6L        | North York       | Upwood Park,North Park,Downsview                                                                                                |     0      |      0      |
# |  50 | M9L        | North York       | Humber Summit                                                                                                                   |     0      |      0      |
# |  51 | M1M        | Scarborough      | Scarborough Village West,Cliffside,Cliffcrest                                                                                   |     0      |      0      |
# |  52 | M2M        | North York       | Willowdale,Newtonbrook                                                                                                          |    43.7635 |    -79.4111 |
# |  53 | M3M        | North York       | Downsview Central                                                                                                               |     0      |      0      |
# |  54 | M4M        | East Toronto     | Studio District                                                                                                                 |     0      |      0      |
# |  55 | M5M        | North York       | Lawrence Manor East,Bedford Park                                                                                                |     0      |      0      |
# |  56 | M6M        | York             | Silverthorn,Mount Dennis,Keelesdale,Del Ray                                                                                     |     0      |      0      |
# |  57 | M9M        | North York       | Humberlea,Emery                                                                                                                 |     0      |      0      |
# |  58 | M1N        | Scarborough      | Cliffside West,Birch Cliff                                                                                                      |     0      |      0      |
# |  59 | M2N        | North York       | Willowdale South                                                                                                                |    43.724  |    -79.4831 |
# |  60 | M3N        | North York       | Downsview Northwest                                                                                                             |     0      |      0      |
# |  61 | M4N        | Central Toronto  | Lawrence Park                                                                                                                   |     0      |      0      |
# |  62 | M5N        | Central Toronto  | Roselawn                                                                                                                        |     0      |      0      |
# |  63 | M6N        | York             | Runnymede,The Junction North                                                                                                    |    43.6756 |    -79.4832 |
# |  64 | M9N        | York             | Weston                                                                                                                          |     0      |      0      |
# |  65 | M1P        | Scarborough      | Wexford Heights,Scarborough Town Centre,Dorset Park                                                                             |     0      |      0      |
# |  66 | M2P        | North York       | York Mills West                                                                                                                 |     0      |      0      |
# |  67 | M4P        | Central Toronto  | Davisville North                                                                                                                |     0      |      0      |
# |  68 | M5P        | Central Toronto  | Forest Hill West,Forest Hill North                                                                                              |     0      |      0      |
# |  69 | M6P        | West Toronto     | The Junction South,High Park                                                                                                    |    43.6622 |    -79.4639 |
# |  70 | M9P        | Etobicoke        | Westmount                                                                                                                       |     0      |      0      |
# |  71 | M1R        | Scarborough      | Wexford,Maryvale                                                                                                                |     0      |      0      |
# |  72 | M2R        | North York       | Willowdale West                                                                                                                 |     0      |      0      |
# |  73 | M4R        | Central Toronto  | North Toronto West                                                                                                              |     0      |      0      |
# |  74 | M5R        | Central Toronto  | Yorkville,North Midtown,The Annex                                                                                               |     0      |      0      |
# |  75 | M6R        | West Toronto     | Roncesvalles,Parkdale                                                                                                           |     0      |      0      |
# |  76 | M7R        | Mississauga      | Canada Post Gateway Processing Centre                                                                                           |     0      |      0      |
# |  77 | M9R        | Etobicoke        | St. Phillips,Richview Gardens,Martin Grove Gardens,Kingsview Village                                                            |    43.6286 |    -79.4853 |
# |  78 | M1S        | Scarborough      | Agincourt                                                                                                                       |     0      |      0      |
# |  79 | M4S        | Central Toronto  | Davisville                                                                                                                      |     0      |      0      |
# |  80 | M5S        | Downtown Toronto | University of Toronto,Harbord                                                                                                   |     0      |      0      |
# |  81 | M6S        | West Toronto     | Swansea,Runnymede                                                                                                               |    43.6492 |    -79.4746 |
# |  82 | M1T        | Scarborough      | Tam O'Shanter,Sullivan,Clarks Corners                                                                                           |     0      |      0      |
# |  83 | M4T        | Central Toronto  | Summerhill East,Moore Park                                                                                                      |     0      |      0      |
# |  84 | M5T        | Downtown Toronto | Kensington Market,Grange Park,Chinatown                                                                                         |     0      |      0      |
# |  85 | M1V        | Scarborough      | Steeles East,Milliken,L'Amoreaux East,Agincourt North                                                                           |     0      |      0      |
# |  86 | M4V        | Central Toronto  | Summerhill West,South Hill,Rathnelly,Forest Hill SE,Deer Park                                                                   |     0      |      0      |
# |  87 | M5V        | Downtown Toronto | South Niagara,Railway Lands,King and Spadina,Harbourfront West,Island airport,Bathurst Quay,CN Tower                            |     0      |      0      |
# |  88 | M8V        | Etobicoke        | New Toronto,Mimico South,Humber Bay Shores                                                                                      |     0      |      0      |
# |  89 | M9V        | Etobicoke        | Thistletown,South Steeles,Silverstone,Mount Olive,Jamestown,Humbergate,Beaumond Heights,Albion Gardens                          |     0      |      0      |
# |  90 | M1W        | Scarborough      | L'Amoreaux West                                                                                                                 |    43.8158 |    -79.328  |
# |  91 | M4W        | Downtown Toronto | Rosedale                                                                                                                        |     0      |      0      |
# |  92 | M5W        | Downtown Toronto | Stn A PO Boxes 25 The Esplanade                                                                                                 |     0      |      0      |
# |  93 | M8W        | Etobicoke        | Long Branch,Alderwood                                                                                                           |     0      |      0      |
# |  94 | M9W        | Etobicoke        | Northwest                                                                                                                       |    43.7189 |    -79.5681 |
# |  95 | M1X        | Scarborough      | Upper Rouge                                                                                                                     |     0      |      0      |
# |  96 | M4X        | Downtown Toronto | St. James Town,Cabbagetown                                                                                                      |     0      |      0      |
# |  97 | M5X        | Downtown Toronto | Underground city,First Canadian Place                                                                                           |     0      |      0      |
# |  98 | M8X        | Etobicoke        | Old Mill North,Montgomery Road,The Kingsway                                                                                     |     0      |      0      |
# |  99 | M4Y        | Downtown Toronto | Church and Wellesley                                                                                                            |     0      |      0      |
# | 100 | M7Y        | East Toronto     | Business Reply Mail Processing Centre 969 Eastern                                                                               |     0      |      0      |
# | 101 | M8Y        | Etobicoke        | Sunnylea,Royal York South East,The Queensway East,Old Mill South,Mimico NE,Kingsway Park South East,King's Mill Park,Humber Bay |     0      |      0      |
# | 102 | M8Z        | Etobicoke        | South of Bloor,Royal York South West,The Queensway West,Mimico NW,Kingsway Park South West                                      |     0      |      0      |
# +-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+------------+-------------+

# %% [markdown]
# <h3>Finally, fill in the blanks with the provided csv list of postal codes/coordinates</h3>

# %%
import io
import requests

# read the file which contains the Postal Codes / Coords
url = "http://cocl.us/Geospatial_data"
df_codes_coordinates = pd.read_csv(url)

# now iterate and replace coords in our dataframe
for index, row in df_final.iterrows():
    if row['Latitude'] == 0.0:
        coords_df = df_codes_coordinates.loc[df_codes_coordinates['Postal Code'] == row['Postcode']]
        for coords_index, coords_row in coords_df.iterrows():
            df_final.loc[index] = [row['Postcode'], row['Borough'], row['Neighborhood'], coords_row['Latitude'], coords_row['Longitude']]

print(tabulate(df_final, headers='keys', tablefmt='psql'))
# Out:
# +-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+------------+-------------+
# |     | Postcode   | Borough          | Neighborhood                                                                                                                    |   Latitude |   Longitude |
# |-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+------------+-------------|
# |   0 | M3A        | North York       | Parkwoods                                                                                                                       |    43.7533 |    -79.3297 |
# |   1 | M4A        | North York       | Victoria Village                                                                                                                |    43.7259 |    -79.3156 |
# |   2 | M5A        | Downtown Toronto | Regent Park,Harbourfront                                                                                                        |    43.6543 |    -79.3606 |
# |   3 | M6A        | North York       | Lawrence Manor,Lawrence Heights                                                                                                 |    43.7185 |    -79.4648 |
# |   4 | M7A        | Queen's Park     | Queen's Park                                                                                                                    |    43.66   |    -79.3904 |
# |   5 | M9A        | Etobicoke        | Islington Avenue                                                                                                                |    43.6679 |    -79.5322 |
# |   6 | M1B        | Scarborough      | Malvern,Rouge                                                                                                                   |    43.7731 |    -79.2578 |
# |   7 | M3B        | North York       | Don Mills North                                                                                                                 |    43.7459 |    -79.3522 |
# |   8 | M4B        | East York        | Parkview Hill,Woodbine Gardens                                                                                                  |    43.7064 |    -79.3099 |
# |   9 | M5B        | Downtown Toronto | Garden District,Ryerson                                                                                                         |    43.6572 |    -79.3789 |
# |  10 | M6B        | North York       | Glencairn                                                                                                                       |    43.7096 |    -79.4451 |
# |  11 | M9B        | Etobicoke        | West Deane Park,Princess Gardens,Martin Grove,Islington,Cloverdale                                                              |    43.6509 |    -79.5547 |
# |  12 | M1C        | Scarborough      | Port Union,Rouge Hill,Highland Creek                                                                                            |    43.7731 |    -79.2578 |
# |  13 | M3C        | North York       | Don Mills South,Flemingdon Park                                                                                                 |    43.7328 |    -79.347  |
# |  14 | M4C        | East York        | Woodbine Heights                                                                                                                |    43.6953 |    -79.3184 |
# |  15 | M5C        | Downtown Toronto | St. James Town                                                                                                                  |    43.6515 |    -79.3754 |
# |  16 | M6C        | York             | Humewood-Cedarvale                                                                                                              |    43.6938 |    -79.4282 |
# |  17 | M9C        | Etobicoke        | Old Burnhamthorpe,Markland Wood,Eringate,Bloordale Gardens                                                                      |    43.6286 |    -79.4853 |
# |  18 | M1E        | Scarborough      | West Hill,Morningside,Guildwood                                                                                                 |    43.7636 |    -79.1887 |
# |  19 | M4E        | East Toronto     | The Beaches                                                                                                                     |    43.6764 |    -79.293  |
# |  20 | M5E        | Downtown Toronto | Berczy Park                                                                                                                     |    43.6544 |    -79.3805 |
# |  21 | M6E        | York             | Caledonia-Fairbanks                                                                                                             |    43.689  |    -79.4535 |
# |  22 | M1G        | Scarborough      | Woburn                                                                                                                          |    43.771  |    -79.2169 |
# |  23 | M4G        | East York        | Leaside                                                                                                                         |    43.7091 |    -79.3635 |
# |  24 | M5G        | Downtown Toronto | Central Bay Street                                                                                                              |    43.658  |    -79.3874 |
# |  25 | M6G        | Downtown Toronto | Christie                                                                                                                        |    43.6695 |    -79.4226 |
# |  26 | M1H        | Scarborough      | Cedarbrae                                                                                                                       |    43.7731 |    -79.2395 |
# |  27 | M2H        | North York       | Hillcrest Village                                                                                                               |    43.8038 |    -79.3635 |
# |  28 | M3H        | North York       | Wilson Heights,Downsview North,Bathurst Manor                                                                                   |    43.7562 |    -79.4398 |
# |  29 | M4H        | East York        | Thorncliffe Park                                                                                                                |    43.7054 |    -79.3494 |
# |  30 | M5H        | Downtown Toronto | Richmond,King,Adelaide                                                                                                          |    43.652  |    -79.3856 |
# |  31 | M6H        | West Toronto     | Dufferin,Dovercourt Village                                                                                                     |    43.669  |    -79.4423 |
# |  32 | M1J        | Scarborough      | Scarborough Village                                                                                                             |    43.7447 |    -79.2395 |
# |  33 | M2J        | North York       | Oriole,Henry Farm,Fairview                                                                                                      |    43.724  |    -79.4831 |
# |  34 | M3J        | North York       | York University,Northwood Park                                                                                                  |    43.7756 |    -79.4935 |
# |  35 | M4J        | East York        | East Toronto                                                                                                                    |    43.6853 |    -79.3381 |
# |  36 | M5J        | Downtown Toronto | Union Station,Toronto Islands,Harbourfront East                                                                                 |    43.6408 |    -79.3818 |
# |  37 | M6J        | West Toronto     | Trinity,Little Portugal                                                                                                         |    43.6479 |    -79.4197 |
# |  38 | M1K        | Scarborough      | Kennedy Park,Ionview,East Birchmount Park                                                                                       |    43.7279 |    -79.262  |
# |  39 | M2K        | North York       | Bayview Village                                                                                                                 |    43.7869 |    -79.386  |
# |  40 | M3K        | North York       | Downsview East,CFB Toronto                                                                                                      |    43.7375 |    -79.4648 |
# |  41 | M4K        | East Toronto     | Riverdale,The Danforth West                                                                                                     |    43.6796 |    -79.3522 |
# |  42 | M5K        | Downtown Toronto | Toronto Dominion Centre,Design Exchange                                                                                         |    43.6472 |    -79.3816 |
# |  43 | M6K        | West Toronto     | Parkdale Village,Exhibition Place,Brockton                                                                                      |    43.6371 |    -79.435  |
# |  44 | M1L        | Scarborough      | Oakridge,Golden Mile,Clairlea                                                                                                   |    43.7111 |    -79.2846 |
# |  45 | M2L        | North York       | York Mills,Silver Hills                                                                                                         |    43.7575 |    -79.3747 |
# |  46 | M3L        | North York       | Downsview West                                                                                                                  |    43.739  |    -79.5069 |
# |  47 | M4L        | East Toronto     | India Bazaar,The Beaches West                                                                                                   |    43.669  |    -79.3156 |
# |  48 | M5L        | Downtown Toronto | Victoria Hotel,Commerce Court                                                                                                   |    43.6482 |    -79.3798 |
# |  49 | M6L        | North York       | Upwood Park,North Park,Downsview                                                                                                |    43.7138 |    -79.4901 |
# |  50 | M9L        | North York       | Humber Summit                                                                                                                   |    43.7563 |    -79.566  |
# |  51 | M1M        | Scarborough      | Scarborough Village West,Cliffside,Cliffcrest                                                                                   |    43.7163 |    -79.2395 |
# |  52 | M2M        | North York       | Willowdale,Newtonbrook                                                                                                          |    43.7635 |    -79.4111 |
# |  53 | M3M        | North York       | Downsview Central                                                                                                               |    43.7285 |    -79.4957 |
# |  54 | M4M        | East Toronto     | Studio District                                                                                                                 |    43.6595 |    -79.3409 |
# |  55 | M5M        | North York       | Lawrence Manor East,Bedford Park                                                                                                |    43.7333 |    -79.4197 |
# |  56 | M6M        | York             | Silverthorn,Mount Dennis,Keelesdale,Del Ray                                                                                     |    43.6911 |    -79.476  |
# |  57 | M9M        | North York       | Humberlea,Emery                                                                                                                 |    43.7248 |    -79.5322 |
# |  58 | M1N        | Scarborough      | Cliffside West,Birch Cliff                                                                                                      |    43.6927 |    -79.2648 |
# |  59 | M2N        | North York       | Willowdale South                                                                                                                |    43.724  |    -79.4831 |
# |  60 | M3N        | North York       | Downsview Northwest                                                                                                             |    43.7616 |    -79.521  |
# |  61 | M4N        | Central Toronto  | Lawrence Park                                                                                                                   |    43.728  |    -79.3888 |
# |  62 | M5N        | Central Toronto  | Roselawn                                                                                                                        |    43.7117 |    -79.4169 |
# |  63 | M6N        | York             | Runnymede,The Junction North                                                                                                    |    43.6756 |    -79.4832 |
# |  64 | M9N        | York             | Weston                                                                                                                          |    43.7069 |    -79.5182 |
# |  65 | M1P        | Scarborough      | Wexford Heights,Scarborough Town Centre,Dorset Park                                                                             |    43.7574 |    -79.2733 |
# |  66 | M2P        | North York       | York Mills West                                                                                                                 |    43.7528 |    -79.4    |
# |  67 | M4P        | Central Toronto  | Davisville North                                                                                                                |    43.7128 |    -79.3902 |
# |  68 | M5P        | Central Toronto  | Forest Hill West,Forest Hill North                                                                                              |    43.6969 |    -79.4113 |
# |  69 | M6P        | West Toronto     | The Junction South,High Park                                                                                                    |    43.6622 |    -79.4639 |
# |  70 | M9P        | Etobicoke        | Westmount                                                                                                                       |    43.6963 |    -79.5322 |
# |  71 | M1R        | Scarborough      | Wexford,Maryvale                                                                                                                |    43.7501 |    -79.2958 |
# |  72 | M2R        | North York       | Willowdale West                                                                                                                 |    43.7827 |    -79.4423 |
# |  73 | M4R        | Central Toronto  | North Toronto West                                                                                                              |    43.7154 |    -79.4057 |
# |  74 | M5R        | Central Toronto  | Yorkville,North Midtown,The Annex                                                                                               |    43.6727 |    -79.4057 |
# |  75 | M6R        | West Toronto     | Roncesvalles,Parkdale                                                                                                           |    43.649  |    -79.4563 |
# |  76 | M7R        | Mississauga      | Canada Post Gateway Processing Centre                                                                                           |    43.637  |    -79.6158 |
# |  77 | M9R        | Etobicoke        | St. Phillips,Richview Gardens,Martin Grove Gardens,Kingsview Village                                                            |    43.6286 |    -79.4853 |
# |  78 | M1S        | Scarborough      | Agincourt                                                                                                                       |    43.7942 |    -79.262  |
# |  79 | M4S        | Central Toronto  | Davisville                                                                                                                      |    43.7043 |    -79.3888 |
# |  80 | M5S        | Downtown Toronto | University of Toronto,Harbord                                                                                                   |    43.6627 |    -79.4    |
# |  81 | M6S        | West Toronto     | Swansea,Runnymede                                                                                                               |    43.6492 |    -79.4746 |
# |  82 | M1T        | Scarborough      | Tam O'Shanter,Sullivan,Clarks Corners                                                                                           |    43.7816 |    -79.3043 |
# |  83 | M4T        | Central Toronto  | Summerhill East,Moore Park                                                                                                      |    43.6896 |    -79.3832 |
# |  84 | M5T        | Downtown Toronto | Kensington Market,Grange Park,Chinatown                                                                                         |    43.6532 |    -79.4    |
# |  85 | M1V        | Scarborough      | Steeles East,Milliken,L'Amoreaux East,Agincourt North                                                                           |    43.8153 |    -79.2846 |
# |  86 | M4V        | Central Toronto  | Summerhill West,South Hill,Rathnelly,Forest Hill SE,Deer Park                                                                   |    43.6864 |    -79.4    |
# |  87 | M5V        | Downtown Toronto | South Niagara,Railway Lands,King and Spadina,Harbourfront West,Island airport,Bathurst Quay,CN Tower                            |    43.6289 |    -79.3944 |
# |  88 | M8V        | Etobicoke        | New Toronto,Mimico South,Humber Bay Shores                                                                                      |    43.6056 |    -79.5013 |
# |  89 | M9V        | Etobicoke        | Thistletown,South Steeles,Silverstone,Mount Olive,Jamestown,Humbergate,Beaumond Heights,Albion Gardens                          |    43.7394 |    -79.5884 |
# |  90 | M1W        | Scarborough      | L'Amoreaux West                                                                                                                 |    43.8158 |    -79.328  |
# |  91 | M4W        | Downtown Toronto | Rosedale                                                                                                                        |    43.6796 |    -79.3775 |
# |  92 | M5W        | Downtown Toronto | Stn A PO Boxes 25 The Esplanade                                                                                                 |    43.6464 |    -79.3748 |
# |  93 | M8W        | Etobicoke        | Long Branch,Alderwood                                                                                                           |    43.6024 |    -79.5435 |
# |  94 | M9W        | Etobicoke        | Northwest                                                                                                                       |    43.7189 |    -79.5681 |
# |  95 | M1X        | Scarborough      | Upper Rouge                                                                                                                     |    43.8361 |    -79.2056 |
# |  96 | M4X        | Downtown Toronto | St. James Town,Cabbagetown                                                                                                      |    43.668  |    -79.3677 |
# |  97 | M5X        | Downtown Toronto | Underground city,First Canadian Place                                                                                           |    43.6484 |    -79.3823 |
# |  98 | M8X        | Etobicoke        | Old Mill North,Montgomery Road,The Kingsway                                                                                     |    43.6537 |    -79.5069 |
# |  99 | M4Y        | Downtown Toronto | Church and Wellesley                                                                                                            |    43.6659 |    -79.3832 |
# | 100 | M7Y        | East Toronto     | Business Reply Mail Processing Centre 969 Eastern                                                                               |    43.6627 |    -79.3216 |
# | 101 | M8Y        | Etobicoke        | Sunnylea,Royal York South East,The Queensway East,Old Mill South,Mimico NE,Kingsway Park South East,King's Mill Park,Humber Bay |    43.6363 |    -79.4985 |
# | 102 | M8Z        | Etobicoke        | South of Bloor,Royal York South West,The Queensway West,Mimico NW,Kingsway Park South West                                      |    43.6288 |    -79.521  |
# +-----+------------+------------------+---------------------------------------------------------------------------------------------------------------------------------+------------+-------------+

# %% [markdown]
# <h2>Part 3 of assignment: Visualize neighborhoods</h2>

# %% [markdown]
# <h3>Display map with raw data - no clustering</h3>

# %%
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't installed folium previously
import folium # map rendering library

# create map of Manhattan using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df_final['Latitude'], df_final['Longitude'], df_final['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3>Perform clustering using KMeans</h3>

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = df_final.drop('Neighborhood', 1)
toronto_grouped_clustering = toronto_grouped_clustering.drop('Borough', 1)
toronto_grouped_clustering = toronto_grouped_clustering.drop('Postcode', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 0, 1, 0, 4, 2, 3, 2, 0], dtype=int32)

# %% [markdown]
# <h3>Finally, display our clustered neighborhoods - you should see 5 different clusters</h3>

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# create exact copy of df_final so we can re-run the code below if needed
df_final_merged = df_final.copy()

# add clustering labels
df_final_merged.insert(0, 'Cluster Labels', kmeans.labels_)

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_final_merged['Latitude'], df_final_merged['Longitude'], df_final_merged['Neighborhood'], df_final_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3>NOTE: I found that this group of 5 clusters seems to provide a good grouping of the different neighborhoods</h3>
